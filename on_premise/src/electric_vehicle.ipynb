# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.window import Window

# %%
spark = SparkSession.builder.appName("electric-vehicle") \
        .master("local[*]") \
        .getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/04/19 21:34:35 WARN Utils: Your hostname, TANATB-PC, resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 26/04/19 21:34:35 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/19 21:34:36 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
df = spark.read.csv("../datasets/ev/Electric_Vehicle_Population_Data.csv",
                    header=True,
                    inferSchema=True)

# %%
df.show(10, truncate=False)
# Out:
# +----------+---------+-----------------+-----+-----------+----------+---------+-------+--------------------------------------+------------------------------------------------------------+--------------+--------------------+--------------+---------------------------+---------------------------------------------+-----------------+
# |VIN (1-10)|County   |City             |State|Postal Code|Model Year|Make     |Model  |Electric Vehicle Type                 |Clean Alternative Fuel Vehicle (CAFV) Eligibility           |Electric Range|Legislative District|DOL Vehicle ID|Vehicle Location           |Electric Utility                             |2020 Census Tract|
# +----------+---------+-----------------+-----+-----------+----------+---------+-------+--------------------------------------+------------------------------------------------------------+--------------+--------------------+--------------+---------------------------+---------------------------------------------+-----------------+
# |1N4AZ0CP6D|King     |Kirkland         |WA   |98034      |2013      |NISSAN   |LEAF   |Battery Electric Vehicle (BEV)        |Clean Alternative Fuel Vehicle Eligible                     |75            |1                   |154635729     |POINT (-122.22901 47.72201)|PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)|53033022203      |
# |5YJ3E1EC8L|Kitsap   |Bainbridge Island|WA   |98110      |2020      |TESLA    |MODEL 3|Battery Electric Vehicle (BEV)        |Clean Alternative Fuel Vehicle Eligible                     |308           |23                  |107518645     |POINT (-122.521 47.62759)  |PUGET SOUND ENERGY INC                       |53035090902      |
# |5YJ3E1EBXJ|King     |Seattle          |WA   |98144      |2018      |TESLA    |MODEL 3|Battery Electric Vehicle (BEV)        |Clean Alternative Fuel Vehicle Eligible                     |215           |37                  |474808813     |POINT (-122.30866 47.57874)|CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA) |53033009000      |
# |ZFAFFAC45R|Thurston |Yelm             |WA   |98597      |2024      |FIAT     |500E   |Battery Electric Vehicle (BEV)        |Eligibility unknown as battery range has not been researched|0             |2                   |273658514     |POINT (-122.60735 46.94239)|PUGET SOUND ENERGY INC                       |53067012412      |
# |5YJYGDEE3L|King     |Kent             |WA   |98030      |2020      |TESLA    |MODEL Y|Battery Electric Vehicle (BEV)        |Clean Alternative Fuel Vehicle Eligible                     |291           |47                  |109579900     |POINT (-122.19975 47.37483)|PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)|53033029507      |
# |WBY1Z4C50F|Snohomish|Mukilteo         |WA   |98275      |2015      |BMW      |I3     |Plug-in Hybrid Electric Vehicle (PHEV)|Clean Alternative Fuel Vehicle Eligible                     |72            |21                  |474837583     |POINT (-122.29196 47.89908)|PUGET SOUND ENERGY INC                       |53061042005      |
# |5YJXCBE28G|King     |Seattle          |WA   |98115      |2016      |TESLA    |MODEL X|Battery Electric Vehicle (BEV)        |Clean Alternative Fuel Vehicle Eligible                     |200           |43                  |103221744     |POINT (-122.31676 47.68156)|CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA) |53033003601      |
# |1G1RB6S51H|Island   |Oak Harbor       |WA   |98277      |2017      |CHEVROLET|VOLT   |Plug-in Hybrid Electric Vehicle (PHEV)|Clean Alternative Fuel Vehicle Eligible                     |53            |10                  |237694698     |POINT (-122.64682 48.29077)|PUGET SOUND ENERGY INC                       |53029970401      |
# |5YJ3E1EA7J|King     |Kirkland         |WA   |98034      |2018      |TESLA    |MODEL 3|Battery Electric Vehicle (BEV)        |Clean Alternative Fuel Vehicle Eligible                     |215           |1                   |287031223     |POINT (-122.22901 47.72201)|PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)|53033022203      |
# |5YJSA1E2XH|King     |Seattle          |WA   |98107      |2017      |TESLA    |MODEL S|Battery Electric Vehicle (BEV)        |Clean Alternative Fuel Vehicle Eligible                     |210           |43                  |329236610     |POINT (-122.38591 47.67597)|CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA) |53033004800      |
# +----------+---------+-----------------+-----+-----------+----------+---------+-------+--------------------------------------+------------------------------------------------------------+--------------+--------------------+--------------+---------------------------+---------------------------------------------+-----------------+
# only showing top 10 rows

# %%
df.count()
# Out:
# 280833
